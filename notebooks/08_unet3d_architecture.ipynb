# %% [markdown]
# # 3D U-Net architecture
#
# Research notebook using synthetic data unless an authorized dataset is configured.

# %%
import torch
from neurogeo.models.unet3d import UNet3D
m=UNet3D(); x=torch.randn(1,4,32,32,32); m(x).shape
