# %% [markdown]
# # Mesh graph refinement concept
#
# Research notebook using synthetic data unless an authorized dataset is configured.

# %%
from neurogeo.models.graph_refiner import MeshBoundaryRefiner
model=MeshBoundaryRefiner(); sum(p.numel() for p in model.parameters())
