# %% [markdown]
# # 3D marching-cubes reconstruction
#
# Research notebook using synthetic data unless an authorized dataset is configured.

# %%
from neurogeo.synthetic import make_brain_tumor_phantom
from neurogeo.geometry import mask_to_mesh
_,_,tumor,_=make_brain_tumor_phantom(); v,f,n=mask_to_mesh(tumor)
len(v), len(f)
