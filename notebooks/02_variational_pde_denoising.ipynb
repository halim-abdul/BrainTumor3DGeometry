# %% [markdown]
# # Variational PDE denoising
#
# Research notebook using synthetic data unless an authorized dataset is configured.

# %%
from neurogeo.synthetic import make_brain_tumor_phantom
from neurogeo.pde import perona_malik_3d, rof_tv_3d
imgs,*_ = make_brain_tumor_phantom()
pm = perona_malik_3d(imgs[3], n_iter=10)
tv = rof_tv_3d(imgs[3])
