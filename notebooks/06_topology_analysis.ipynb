# %% [markdown]
# # Topology of segmentation masks
#
# Research notebook using synthetic data unless an authorized dataset is configured.

# %%
from neurogeo.synthetic import make_brain_tumor_phantom
from neurogeo.topology import topology_features
_,_,tumor,_=make_brain_tumor_phantom(); topology_features(tumor)
