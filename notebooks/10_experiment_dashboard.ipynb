# %% [markdown]
# # Experiment dashboard
#
# Research notebook using synthetic data unless an authorized dataset is configured.

# %%
import pandas as pd
df=pd.read_csv("../experiments/synthetic_training_log.csv")
df.tail()
