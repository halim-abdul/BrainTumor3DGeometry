# %% [markdown]
# # Position and size relative to brain
#
# Research notebook using synthetic data unless an authorized dataset is configured.

# %%
from neurogeo.synthetic import make_brain_tumor_phantom
from neurogeo.location import normalized_position, volume_fraction
_,brain,tumor,_=make_brain_tumor_phantom(); normalized_position(tumor,brain), volume_fraction(tumor,brain)
