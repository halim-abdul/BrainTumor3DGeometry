# %% [markdown]
# # Overlap and surface metrics
#
# Research notebook using synthetic data unless an authorized dataset is configured.

# %%
from scipy.ndimage import binary_dilation
from neurogeo.synthetic import make_brain_tumor_phantom
from neurogeo.metrics import metric_bundle
_,_,gt,_=make_brain_tumor_phantom(); pred=binary_dilation(gt,iterations=1)
metric_bundle(pred,gt)
